# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Classify the health of a fetus as Normal, Suspect or Pathological using CTG data

# %%
df = pd.read_csv('./fetal_health.csv')
df.plot()
# Out:
# <AxesSubplot:>

# %%
sns.set()

# %% [markdown]
# ## fetal heart rate (FHR) accelerations associated with fetal movements is considered a sign of fetal well-being.

# %%
x = df['accelerations'].values
y = df['fetal_movement'].values
plt.plot(x , color = 'red')
plt.plot(y , color = 'blue')
